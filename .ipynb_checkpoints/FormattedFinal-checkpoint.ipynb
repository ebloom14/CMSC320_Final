# %% [markdown]
# # <h1 style = "font-size: 40px;"><em>Final Tutorial</em></h1>
# ### <u>By: Julian Spencer && Eric Bloom</u>
# ## Published: December 12, 2022<br>Last Updated: December 16, 2022
# ----------------------------------------------------------------------------------------
# ### <h2>Table of Contents</h2>
# <ol style="margin: 20px; font-size: 16px;">
#     <li>Introduction</li>
#     <li>Data Data Wrangling
#         <ol>
#             <li>Meeting the Data</li>
#             <li>Data Manipulation</li>
#         </ol>
#     <li>Porch & Deck Correlations</li>
#         <ol>
#             <li>Linear Regression regarding Decks and Porches</li>
#             <li>Comparing Types of Porches with Month Sold</li>
#         </ol>
#     <li>Porch Type Distributions</li>
#         <ol>
#             <li>Enclosed Porche Area VS Month Sold</li>
#             <li>Screened Porch Area VS Month Sold</li>
#             <li>3-Season Porch Area VS Month Sold</li>
#         </ol>
#     <li>FirePlace Correlation Data</li>
#         <ol>
#             <li>Mean Sales Prices by Fireplace and Month Sold</li>
#             <li>Fireplace Qualiy VS Price of House Sold</li>
#         </ol>
#     <li>The Garage Trials</li>
#         <ol>
#             <li>Trends in Garage Types VS Month of Sale</li>
#         </ol>
#     <li>Cold Yet?</li>
#         <ol>
#             <li>Number of Houses Sold by Heating/Cooling Quality and Month</li>
#         </ol>
#     <li>General Sale Price VS Month of Sale Distribution</li>
#         <ol>
#             <li>Sale Price VS Month Scattar Plot</li>
#             <li>Sale Price VS Month Violin Plot</li>
#         </ol>
#     <li>Proving/Disproving the Null</li>
#         <ol>
#             <li>Fitting a Linear Regression Model for Month w/ I. Term for Total Amenities</li>
#             <li>Making a Support Vector Machine</li>
#         </ol>
#     <li>Conclusion</li>
# </ol>

# %% [markdown]
# -----------------------------------------------------------------------
#
# ## <h2>1.) Introduction</h2>
# <br>
# <p style = "font-size: 16px;">The housing market has plenty of factors that keep the numbers changing for home sales, including <a href="https://www.nar.realtor/blogs/economists-outlook/seasonality-in-the-housing-market"><u>seasonality</u></a>. Past data shows that sales activity increase during the warmer months. We want to find out, given a particular type of house, is there anything that can make it look more appealing during different seasons? We understand there exist a variety of house types, but there are still a finite number of house amenities. We shall take a look at a sample of these features in attempts to seek a correlation between the timing and pricing of the house sold. Specifically, we want to find out what type of features make a house more valuable during certain seasons. We will focus on three amenities: fireplaces, porches/decks,and garage type. To achieve our goal, we plan to use all the skills we aquired over the semester in working with python, pandas, matplotlib, and more to analyze a dataset of home sales data.</p>
# <p style = "font-size: 16px;">Overall, we believe that our analysis will provide valuable insights into the correlation between home sales and seasons, and help us understand which amenities are most valuable in different seasons. We hope that our findings will be useful for homeowners and real estate agents looking to optimize the sale of their homes.</p>
#
# <p style = "font-size: 16px;">Our null hypothesis suggests that there is no relationship between the number of houses sold during a particular season and the amenities of the house. We will test this hypothesis using statistical analysis and machine learning techniques. </p>
#
# Old Hyp: there is no correlation with houses being sold and the amentities in which the houses contain.
#
# <br>
#
# --------------------------------------------------------------------------
#
# ## <h2>2.) Data Wrangling</h2><br><h3>2.A.) Meeting the Data</h3>
# <br>
# <p style = "font-size: 16px;">The dataset of house sales we took is from Ames, Iowa. This dataset contains over 80 columns and needs to be reduced in order to target our focus only on relevant data. The first step would be to import the data for use and to drop any columns that are not related to home amenities. In order to build an effective model, we will need to carefully identify and select the relevant columns. </p>

# %%
import folium
import requests
import csv
import pandas as pd

house_df = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
house_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## <h3>2.B.) Data Manipulation</h3>
# <br>
# <p style = "font-size: 16px;">We need to gut a majority of the columns since they either prove to be irrelavent for proving our hypothesis, or they just add little predictive power. For this drop any columns describing the house materials, zoning location, structure details, and any data that proves not to be well distributed. We also rename certain values and sort the data in accordance to the month sold as a convenience for plotting some of our figures. </p>

# %%
house_df = house_df.drop(columns = ["LandContour","Utilities","Street","Alley","LandSlope","MasVnrType","Condition2","Heating","Electrical","MasVnrArea","RoofMatl","BsmtFinSF2","BsmtCond","ExterCond","Foundation","GarageFinish","LowQualFinSF","Functional","YearBuilt","YearRemodAdd","ExterQual","MSSubClass","MSZoning","LotConfig","LotFrontage","LotArea","LotShape","MiscFeature","MiscVal","BldgType","HouseStyle","Neighborhood","Id","Condition1","OverallQual","OverallCond","RoofStyle","Exterior1st","Exterior2nd","BsmtQual","BsmtExposure","BsmtFinType1","BsmtFinSF1","BsmtFinType2","BsmtUnfSF","TotalBsmtSF","1stFlrSF","2ndFlrSF","GrLivArea","BsmtHalfBath","BsmtFullBath","BedroomAbvGr","KitchenAbvGr","KitchenQual","TotRmsAbvGrd","GarageYrBlt","GarageCars","FullBath","HalfBath","GarageCond","Fence","SaleType","SaleCondition","PavedDrive","GarageArea","GarageQual","PoolArea","PoolQC"])

# %%
house_df.rename(columns = {'3SsnPorch':'SeasonalPorch'}, inplace=True)

# %%
## Replace the initial values of the entries in the MoSold column from integers to strings that represent 
## the months of the year 
house_df['MoSold'].replace(1,'Jan',inplace=True)
house_df['MoSold'].replace(2,'Feb',inplace=True)
house_df['MoSold'].replace(3,'Mar',inplace=True)
house_df['MoSold'].replace(4,'Apr',inplace=True)
house_df['MoSold'].replace(5,'May',inplace=True)
house_df['MoSold'].replace(6,'June',inplace=True)
house_df['MoSold'].replace(7,'July',inplace=True)
house_df['MoSold'].replace(8,'Aug',inplace=True)
house_df['MoSold'].replace(9,'Sept',inplace=True)
house_df['MoSold'].replace(10,'Oct',inplace=True)
house_df['MoSold'].replace(11,'Nov',inplace=True)
house_df['MoSold'].replace(12,'Dec',inplace=True)

# %%
 months = { "Jan": 1,
         "Feb": 2,
         'Mar': 3,
         'Apr': 4,
         'May': 5,
         'June': 6,
         'July': 7,
         'Aug': 8,
         'Sept': 9,
         'Oct': 10,
         'Nov': 11,
         'Dec': 12,
    }

def month(series):
    
    return series.apply(lambda x: months.get(x, 1000))
        
house_df.sort_values(by=['MoSold'], key = month, inplace=True)
house_df
# Out:
#      HeatingQC CentralAir  Fireplaces FireplaceQu GarageType  WoodDeckSF  \
# 729         TA          Y           0         NaN     Detchd           0
# 691         Ex          Y           2          Ex     Attchd         382
# 711         Gd          Y           0         NaN     Detchd          68
# 59          Ex          Y           0         NaN     Detchd         196
# 787         Ex          Y           0         NaN    BuiltIn           0
# ...        ...        ...         ...         ...        ...         ...
# 574         TA          Y           0         NaN    BuiltIn          35
# 707         Ex          Y           1          Gd     Attchd         192
# 573         Ex          Y           1          TA    BuiltIn         100
# 1296        Gd          Y           0         NaN     Attchd         192
# 720         TA          Y           1          TA     Attchd         114
#
#       OpenPorchSF  EnclosedPorch  SeasonalPorch  ScreenPorch MoSold  YrSold  \
# ...

# %% [markdown]
# ## <h2>3.) Porch & Deck Correlations</h2>
# <br>
# <h3>3.A.) Linear Regression regarding Decks and Porches</h3>
# <br>
# <p style = "font-size: 16px;">The first feature we investigate are the porches and decks. These plots show the relationship between the sale price vs the area of the porches. We first filter the data to only include houses that have a non-zero area for the respective porch type, in order to exclude houses without a porch and avoid bias. Then, we use the scikit-learn library's LinearRegression class to fit a linear regression model to the data for each porch type. The resulting model is then used to generate predictions for porch area values between the minimum and maximum observed values. Finally, we print the slope of the fitted regression lines, and create scatter plots of the observed data with the fitted regression lines overlaid.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

wood = house_df.query('WoodDeckSF != 0')
porch = house_df.query('OpenPorchSF != 0')

X_wood = wood['WoodDeckSF'].values.reshape(-1,1)
X_porch = porch['OpenPorchSF'].values.reshape(-1,1)
Y_w = wood['SalePrice'].values
Y_p = porch['SalePrice'].values

reg = LinearRegression()
reg2 = LinearRegression()

prediction_wood = np.linspace(min(X_wood), max(X_wood)).reshape(-1, 1)
prediction_porch = np.linspace(min(X_porch), max(X_porch)).reshape(-1, 1)

reg.fit(X_wood, Y_w)
reg2.fit(X_porch, Y_p)

wood_pred = reg.predict(prediction_wood)
porch_pred = reg2.predict(prediction_porch)
print('Slope for Wood Deck Area vs House Price Regression: %f'%reg.coef_[0])
print('Slope for Open Porch Area vs House Price Regression: %f'%reg2.coef_[0])

wood.plot.scatter('WoodDeckSF','SalePrice', color= 'b')
plt.plot(prediction_wood, wood_pred, color='red', linewidth=3)
plt.title("Wood Deck Square Feet vs Sale Price")
plt.xlabel('Wood Deck Area in Square Feet')
plt.ylabel('House Sale Price')
porch.plot.scatter('OpenPorchSF','SalePrice', color= 'b')
plt.plot(prediction_porch, porch_pred, color='red', linewidth=3)
plt.title("Porch Square Feet vs Month Sold")
plt.xlabel("Open porch Area in Square Feet")
plt.show()
# Out:
# Slope for Wood Deck Area vs House Price Regression: 149.854728
# Slope for Open Porch Area vs House Price Regression: 106.935459

# %% [markdown]
# ## <h3>3.A.) Open Porches vs Wooden Deck Summary</h3>
# <p style = "font-size: 16px;">With some notable exceptions, we see that the data is skewed towards having a lower average porch area, with a lower general sales price. We can also notice that on average wooden decks have more square area than an open porch. This correlates to the regression lines generated because the slope for wooden deck area vs price is slightly higher than the slope from open porch area vs price. The regression lines generated have a very small increasing slope, but yet still shows that as the porch area increases so does the price of the house.</p>
#
#
# <p style = "font-size: 16px;">Based on this information, it is hard to say if having an open porch vs a wooden deck has any more influence on the price of the house by itself. But it is fairly likely that houses with larger porches will have a higher sale price. Additionally, since the data shows that the relationship between open porch area and sale price is weak, it may prove more useful to focus on seasonal purchasing trends.</p>

# %% [markdown]
# ## <h3>3.B.) Comparing Types of Porches with Month Sold</h3>
# <br>
# <p style = "font-size: 16px;">The purpose of this code is to create scatter plots of three different porch areas (enclosed, screened, and 3-season) versus the month in which the house was sold. The data is filtered to only include houses that have a non-zero area for the respective porch type, and the resulting data is plotted using matplotlib's scatter() function. The color of each plotted point corresponds to the porch type (enclosed porches are red, screened porches are blue, and 3-season porches are green).

# %%
closed = house_df.query('EnclosedPorch != 0')
screen = house_df.query('ScreenPorch != 0')
season = house_df.query('SeasonalPorch != 0')

plt.scatter(closed['MoSold'],closed['EnclosedPorch'], color= 'r')
plt.title("Enclosed Porch Area vs Month Sold")
plt.xlabel("Month Sold")
plt.ylabel('Area in Square Feet')
screen.plot.scatter('MoSold','ScreenPorch', color= 'b')
plt.title("Screen Porch Area vs Month Sold")
plt.xlabel('Month Sold')
plt.ylabel('Area in Square Feet')
season.plot.scatter('MoSold','SeasonalPorch', color= 'g')
plt.title('3 Season Porch Area vs Month Sold')
plt.xlabel('Month Sold')
plt.ylabel('Area in Square Feet')
# Out:
# Text(0, 0.5, 'Area in Square Feet')

# %% [markdown]
# ## <h3>3.B.) Summary</h3>
# <p style = "font-size: 16px;">These plots differ dramatically and have very different trends and correlations. When looking at the distribution of enclosed porch area versus the month sold, we can see that it starts out with a very steady upwards trend until July, at which point there is a sudden drop in the amount of square footage of porch that is included with houses that are sold. This may indicate that buyers are less interested in houses with enclosed porches during the summer months, or that the supply of such houses is lower at that time. Further analysis would be needed to determine the exact cause of this trend. The next would be screened portch area for houses sold in each month and right off the bat, we see that the data is more sparse for this type of porch. You can work out a very slight increasing trend amoung the amount of square footage of porch a house is sold with. Just like with the enclosed porch area, we see a huge spike in sales in the summer months of June and July, but this time the datapoints are mainly outliers as we see the majority of the large screened porches (>300 Square Feet) being sold. Lastly, we see that the three season porch plot is even more sparse then the screened porches before it. This makes it very difficult to see if a 3 season porch has any correlation with month at all. More data of houses with 3 season porch sales will be needed to say something about it's trend. Still, it is interesting to see that the outliers for large seasonal porches only exist during the warmer months where having a nice porch is more desirable.</p>

# %% [markdown]
# --------------------------------------------------------------------------
#
# ## <h2>4.) Porch Type Distributions</h2><br><h3>4.A.) Enclosed Porche Area VS Month Sold</h3>
# <br>
# <p style = "font-size: 16px;">We would like to better examine the trend of the porch area a house has vs the month it was sold. We can accomplish this by making a violin plot of each.</p>

# %%
import seaborn

fig, ax = plt.subplots()

seaborn.violinplot(ax = ax,
               data = closed,
               x = 'MoSold',
               order = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec'],
               y = 'EnclosedPorch',
               hue = None,
               split = True)
plt.title("Enclosed Porch distribution")
plt.xlabel('Month Sold')
plt.ylabel('Area in Square Feet')
plt.show()

# %% [markdown]
# ## <h3>4.A.) Summary</h3>
# <p style = "font-size: 16px;">We see that the average of each month stays relatively steady with small peaks and valleys up until about July which is the exact same trend that we saw in the scatter plot in 3B, thus confirming our intuition about that trend to be accurate. Within this January to June time frame we also can look at the distribution of porch area per month. It is obvious that January had a very 'bottom-heavy' distribution where the most houses were sold with low porch area compared to any month. However, this bottom heavy distribution seems to fade after Febuary leading to March which has a very skinny distribution. This can be equated to the obvious outlier (or outliers) that the month had. we see that the distribution seems get back to the way it was in April and then we get to the summer months which all have a more symmetric distribution, but still a very similar average. After the summer months we see a dip in sales with greater (> ~100 Square Feet) square footage of porches with a sudden increase in November. This month we see that there is a 'top-heavy' distribution with the greatest average out of every month. Then we see our lowest average porch area sold around December. The trend so far is that summer months generally see the most consistent porch sales, while other months have more of an unpredictible distribution.</p>

# %% [markdown]
# ## <h3>4.B.) Screened Porch Area VS Month Sold</h3>
# <br>
# <p style = "font-size: 16px;"></p>

# %%
fig, ax = plt.subplots()

seaborn.violinplot(ax = ax,
               data = screen,
               x = 'MoSold',
                order=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec'],
               y = 'ScreenPorch',
               hue = None,
               split = True)
plt.title("Screen Porch distribution")
plt.xlabel('Month Sold')
plt.ylabel('Area in Square Feet')
plt.show()

# %% [markdown]
# ## <h3>4.B.) Summary</h3>
# <p style = "font-size: 16px;">There seems to be a correlation of a very bottom-heavy distribution for the months of January, april, and september. This is similar to what was found above with enclosed porches as January had a similar distrubution, but just had more datapoints. All other distributions per month have relativly symmetric distribution. Again however, we do see that the summer months have a very different distribution then any other month's distributions'. This further solidifies that there could be a correlation between general porch area and house sales in the summer months.</p>

# %% [markdown]
# ## <h3>4.C.) 3-Season Porch Area VS Month Sold</h3>
# <br>
# <p style = "font-size: 16px;">Now we will look at seasonal porch square feet vs the month sold. It is important to know that there are less datapoints in general as a very small amount of houses in the dataset contianed seasonal porches. Not every month is listed in this plot, which represents no sale data of seasonal porches during that month.</p>

# %%
fig, ax = plt.subplots()

seaborn.violinplot(ax = ax,
               data = season,
               x = 'MoSold',
                   order=['Feb','May','June','July','Oct','Nov'],
               y = 'SeasonalPorch',
               hue = None,
               split = True)
plt.title("Seasonal Porch distribution")
plt.xlabel('Month Sold')
plt.ylabel('Area in Square Feet')
plt.show()

# %% [markdown]
# ## <h3>4.C.) Summary</h3>
# <p style = "font-size: 16px;">This plot cannot be compared as much to the other two above as we know from the scatter plot that there is less datapoints for seasonal porches. We can see that Febuary, June, and Novermber has short and thick mostly symmetrical distributions while May, July, and October had more elongated symmetrical distributions. Yet, it is interesting to note that July has the highest mean of seasonal porch area, where we already know house sales are higher. Nonetheless, there was no evidence given from the sparse scatterplot that this results from a greater number of houses sold during July, as we see more being sold in October with smaller porch areas. More data is necessary to know for sure. </p>

# %% [markdown]
# --------------------------------------------------------------------------
#
# ## <h2>5.) FirePlace Correlation Data</h2><br><h3>5.A.) Mean Sales Prices by Fireplace and Month Sold</h3>
# <br>
# <p style = "font-size: 16px;">Moving on, we want to see if there is some sort of correlation with the number of fireplaces a house is sold with within a given month versus the sale price of the house. Specifically, we would like to focus on any correlation that shows up relating to fireplace sales in the winter months.</p>

# %%
## Group the data by the 'Fireplace' column and the 'MoSold' column
grouped_data = house_df.groupby(['Fireplaces', 'MoSold'])

## Calculate the mean sales price for each group
mean_sales_price = grouped_data['SalePrice'].mean()

# %%
## Unstack the grouped data to create a DataFrame with one column per 'Fireplace' value
unstacked_data = mean_sales_price.unstack(level=0)
unstacked_data.sort_values(by=['MoSold'], key = month, inplace=True) 
## NOTE: This call is static and cannot be ran twice without errors

# %%
## Plot the resulting DataFrame using a bar chart
unstacked_data.plot(kind='bar', width=0.8)
plt.title("Mean Sales Prices by Fireplace and Month Sold", fontsize=16, fontstyle='italic')
plt.xlabel("Month Sold")
plt.ylabel("Sales Price")
plt.legend(bbox_to_anchor=(1.149,1.017))
plt.show()

# %% [markdown]
# ## <h3>5.A.) Summary</h3>
# <p style = "font-size: 16px;">Overall, we see that there is an obvious correlation between a higher house sale price and having 1 or more fire places. Most houses with 2 fireplaces on average sold for more in the months of January, March, and April. However, our prediction that houses with more fireplaces would have a higher sale price in the winter season was not necessarily correct, as September, October, November, and December all had relatively low sale prices for houses with 2 fireplaces. There is a trend with houses that have a single fireplace, with high prices in January decreasing into March, April, and May before bottoming out in June, then rising in July and averaging out for the winter seasons.</p>

# %% [markdown]
# ## <h3>5.B.) Fireplace Qualiy VS Price of House Sold</h3>
# <br>
# <p style = "font-size: 16px;">We originally considered dropping the 'FireplaceQu' column due to a high percentage of NAN values. This column captures data surrounding the quality of the fireplace. We decided to analyze the fewer non-NAN values we had in relation to the home sale prices. The "Ex" value correlates with excellent quality, the "Gd" with good quality, "Fa" with fair quality, "Ta" with typical, and "Po" with poor quality. </p>

# %%
fig, ax = plt.subplots()
seaborn.violinplot(ax = ax,
               data = house_df,
               x = 'FireplaceQu',
               y = 'SalePrice',
               hue = None,
               split = True)
plt.title("Fireplace Quality vs. Sale Price Distribution")
plt.ylabel('House Sale Price')
plt.xlabel('Fireplace Quality')
plt.show()

# %% [markdown]
# ## <h3>5.B.) Summary</h3>
# <p style = "font-size: 16px;">
#     Just looking at the violinplot, we dont see much of a price change between a house with a fireplace in good condition or fair/typical condition. However, to little surprise we do see a trend in lower house pricing for houses with poor quality fireplaces, and higher pricing for houses with fireplaces of excellent quality.
#
#     Overall, we see that there is an obvious correlation between a higher house sale price and having 1 or more fire places. Most houses with 2 fireplaces on average sold for more in the months of January, March, and April. However, our prediction that houses with more fireplaces would have a higher sale price in the winter season was not necessarily correct, as September, October, November, and December all had relatively low sale prices for houses with 2 fireplaces. There is a trend with houses that have a single fireplace, with high prices in January decreasing into March, April, and May before bottoming out in June, then rising in July and averaging out for the winter seasons.</p>

# %% [markdown]
# -------------------------------------------------------------
# ## <h2>6.) The Garage Trials</h2><br><h3>6.A.) Trends in Garage Types VS Month of Sale</h3>
# <br>
# <p style = "font-size: 16px;"></p>

# %%
X = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
det = []
att = []
for i in range(0,12):
    month = house_df.loc[house_df['MoSold'] == X[i]]
    month_att = month['GarageType'].value_counts()['Attchd']
    month_det = month['GarageType'].value_counts()['Detchd']
    att.append(month_att)
    det.append(month_det)

   
br1 = np.arange(len(X))
br2 = [X + 0.25 for X in br1]
plt.bar(X,att,color='blue', width = 0.25,
        edgecolor ='grey', label ='Attached')
plt.bar(br2,det, color='red', width = 0.25,
        edgecolor ='grey', label ='Detached')
plt.legend()
plt.title("Number of Garage Types vs Month Sold")
plt.xlabel('Month Sold')
plt.ylabel('Number of Garage Type Sold')
plt.show()

# %% [markdown]
# ## <h3>6.A.) Summary</h3>
# <p style = "font-size: 16px;">Here we see an obvious trend from both attached and detached garages that has a normal looking distribution with an ever so slight left tail. Attached garage sale quantities steadily rise from January through June, where they peak and then take a sudden and drastic decline which continues until September. This general trend follows for detached garage sales as well. At this point there does seem to be more of a correlation with most ammentities and the summer season rather than the winter season which should be examined further.</p>

# %% [markdown]
# -------------------------------------------------------------
# ## <h2>7.) Cold Yet?</h2><br><h3>7.A.) Number of Houses Sold by Heating/Cooling Quality and Month</h3>
# <br>
# <p style = "font-size: 16px;">Here we can set out to see if there is a correlation with AC quality and purchases in the winter season versus the summer season.</p>

# %%
barWidth = 0.25
ex = []
gd = []
ta = []
fa = []
po = []

for i in range(0,12):
    month = house_df.loc[house_df['MoSold'] == X[i]]
    if 'Ex' in month.values:
        E = month['HeatingQC'].value_counts()['Ex']
        ex.append(E)
    else:
        ex.append(0)
        
    if 'Gd' in month['HeatingQC'].values:
        G = month['HeatingQC'].value_counts()['Gd']
        gd.append(G)
    else:
        gd.append(0)
        
    if 'Fa' in month['HeatingQC'].values:
        F = month['HeatingQC'].value_counts()['Fa']
        fa.append(F)
    else:
        fa.append(0)
        
    if 'TA' in month['HeatingQC'].values:
        T = month['HeatingQC'].value_counts()['TA']
        ta.append(T)
    else:
        ta.append(0)
        
    if 'Po' in month['HeatingQC'].values:
        P = month['HeatingQC'].value_counts()['Po']
        po.append(P)
    else:
        po.append(0)

br1 = np.arange(len(X))
br2 = [X + barWidth for X in br1]
br3 = [X + barWidth for X in br2]
br4 = [X + barWidth for X in br3]
br5 = [X + barWidth for X in br4]

plt.bar(X,ex,color='blue', width = barWidth,
        edgecolor ='grey', label ='Excellent')
plt.bar(br2,gd, color='red', width = barWidth,
        edgecolor ='grey', label ='Good')
plt.bar(br3,ta, color='green', width = barWidth,
        edgecolor ='grey', label ='Typical')
plt.bar(br4,fa, color='purple', width = barWidth,
        edgecolor ='grey', label ='Fair')
plt.bar(br5,po, color='orange', width = barWidth,
        edgecolor ='grey', label ='Poor')
plt.legend()
plt.title('Number of AC Quality Type vs Month Sold')
plt.xlabel('Month Sold')
plt.ylabel('Number of AC Quality Type Sold')
plt.show()

# %% [markdown]
# ## <h3>7.A.) Summary</h3>
# <p style = "font-size: 16px;">Here there is an absolutely staggering resemblance in distribution compared to the garage sale quantities vs month sold distribution above. Not only that, but all AC Quality types seem to have the exact same general distribution (except for the 'poor' quality type since the dataset has very little homes that have poor AC). The trend throughout all types shows an increase in the number of houses that have any quality type of AC from January to July just like we saw above. And then the same decrease after the summer season ends. Two distributions showing the general trend of more sales in the summer for all measurements of a fireplace, leads us to believe that there may not be a correlation between the home features and the timing of the sale.</p>

# %% [markdown]
# ## <h2>8.) General Sale Price VS Month of Sale Distribution</h2>
# <br>
# <p style = "font-size: 16px;">Now we really want to take a deep dive of JUST House Sale Price and month sold. This will attempt to give us an idea of what is going on in the bigger picture.</p>

# %%
fig, ax = plt.subplots()
seaborn.violinplot(ax = ax,
               data = house_df,
               x = 'MoSold',
                order=['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec'],
               y = 'SalePrice',
               hue = None,
               split = True)
plt.title("Month Sold vs. Sale Price Distribution")
plt.title('House Price vs Month Sold')
plt.xlabel('Month Sold')
plt.ylabel('House Sale Price')
plt.show()

# %% [markdown]
# ## <h3>8.B.) Summary</h3>
# <p style = "font-size: 16px;">This violin plot shows a relativly uniform/linear distributin of averages of house sale price amoung all indvidual months. Most of which have the same general symmetry with alot of month distriutions being symmetric (yet thick) around their center. This leads us to believe that house sales are relatively predictable and all fall in the same general range no matter the month.</p>
#
# <p>NOTE(Julian): I dont see much statistical significance here. I think we should cut section 8</p>

# %% [markdown]
# ## <h2>9.) Proving/Disproving the Null</h2><br><h3>9.A.) Fitting a Linear Regression Model for Month w/ I. Term for Total Amenities</h3>
# <br>
# <p style = "font-size: 16px;">We want to continue looking at the big picure here by using statsmodels's api ols model to essentially attempt to prove our hypothesis. We will be fitting a linear regression model for House Sales Price including a term for an interaction between Month and the Total amount of All Amenities (ONLY ONES WE HAVE EXAMINED) and year. This will allow us to summarize the stats it gives including p-value which is what we want for throwing out, or not throwing out our hypothesis.</p>

# %%
## Calculate the number of ammentites we looked at throughout the dataset
def calculate_amenities(row):
    amenities = 0
    if row['HeatingQC'] != 'NaN':
        amenities += 1
    amenities += row['Fireplaces']
    if row['GarageType'] != 'NaN':
        amenities += 1
    if row['WoodDeckSF'] > 0:
        amenities += 1
    if row['OpenPorchSF'] > 0:
        amenities += 1
    if row['SeasonalPorch'] > 0:
        amenities += 1
    if row['ScreenPorch'] > 0:
        amenities += 1
    if row['EnclosedPorch'] > 0:
        amenities += 1
    return amenities

## Use the apply function to calculate the total amount of ammentiteis for 
house_df['total_amenities'] = house_df.apply(calculate_amenities, axis=1)

# %%
import statsmodels.formula.api as smf

# create a formula for the model
formula = 'SalePrice ~ MoSold + total_amenities + MoSold:total_amenities'

# fit the model to the data
model = smf.ols(formula, data=house_df).fit()

# print a summary of the fitted model
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     28.02
# Date:                Fri, 16 Dec 2022   Prob (F-statistic):           1.02e-98
# Time:                        02:12:02   Log-Likelihood:                -18273.
# No. Observations:                1460   AIC:                         3.659e+04
# Df Residuals:                    1436   BIC:                         3.672e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## <h3>9.A.) Summary</h3>
# <p style = "font-size: 16px;">Say some stuff about the p-values</p>

# %% [markdown]
# <h3>9.B.) Making a Support Vector Machine</h3>
# <br>
# <p style = "font-size: 16px;">The goal here is to fit an SVM classifier to the MoSold, GarageType, and HeatingQC columns in the house_df DataFrame and encodes the categorical variables as numeric using the get_dummies function, and plots the decision boundary and the points in the dataset for each month. It shold be noted that we used 'GarageType' and 'HeatingQC' as the features for this SVM as we found that these may have the greatest correlation of all amenities.</p>

# %%
import datetime
from sklearn.svm import SVC

# select the features and target for the model
X = house_df[['MoSold', 'GarageType', 'HeatingQC']]
y = house_df['SalePrice']

# encode the categorical variables as numeric
X = pd.get_dummies(X)

# create a mesh of points to plot the decision boundary
h = .02  # step size in the mesh
xx = np.arange(X[['MoSold_Jan']].min().values[0], X[['MoSold_Jan']].max().values[0], h)

# fit an SVM classifier to the data and plot the decision boundary for each dummy column
for month in ['MoSold_Jan', 'MoSold_Feb', 'MoSold_Mar', 'MoSold_Apr', 'MoSold_May', 'MoSold_June',
              'MoSold_July', 'MoSold_Aug', 'MoSold_Sept', 'MoSold_Oct', 'MoSold_Nov', 'MoSold_Dec']:
    X_month = X[[month]]
    clf = SVC(kernel='linear', C=1, decision_function_shape='ovo', class_weight='balanced')
    clf.fit(X_month, y)
    # predict the class for each point in the mesh
    Z = clf.predict(xx.reshape(-1, 1))
    month_name = month.replace('MoSold_', '')
    # plot the decision boundary and the points
    plt.scatter(X_month, y, c=y, cmap=plt.cm.coolwarm)
    plt.plot(xx, Z, c='k')
    plt.xlabel(month_name)
    plt.ylabel('Sale price')
    plt.title('SVM decision boundary for ' + month_name)
    plt.show()
# Out:
# /home/ebloom14/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /home/ebloom14/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /home/ebloom14/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /home/ebloom14/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /home/ebloom14/.local/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ## <h3>9.A.) Summary</h3>
# <p style = "font-size: 16px;">Try to interpret this shit the best you can. See if there is patterns between differing and similar months bassed on season.</p>

# %% [markdown]
# --------------------------------------------------------------------------
# ## <h2>10.) Conclusion</h2>
# <br>
# <p style = "font-size: 16px;">Based on our analysis of data from 2006 to 2010, we found that there were only some weak correlations between some amenities and summer seasons, but not for winter seasons. One factor that could have influenced these trends is the <a href="https://www.uwp.edu/learn/departments/economics/upload/gwartney-summary-of-financial-crisis.pdf"><u>2008 market crash</u></a>, which was a major economic recession that had significant impacts on the housing market. Another factor could simply be that house buyers have higher priorities when looking for a house, more important to them than the amendities.</p>
# <p style = "font-size: 16px;">Overall, we found that there was little to no significant correlation between seasonal sales and homes having decks. However, we did find some correlations with summer sales and porches of all types. We also found a great correlation between the number of houses with AC of any quality type and the prevalence of garage sales. Nontheless, it is important to note that the market rises every summer and it is not supported that the amendities had any influence in this rise of prices. Especially because it turns out they all share the same behavior in the distribution, regardless of classification of AC quality, porch type, or garage type.</p>
# <p style = "font-size: 16px;"><b>Regarding the trend in both the garage sale data and the AC quality data, It's possible that there is a relationship between the two, but without more information it's difficult to say for sure. It's worth considering that there could be other factors at play that are causing this trend to occur. For example, it could be that people are more likely to pay attention to their AC units and make upgrades or repairs in the summer months because they are using them more frequently and want to ensure that they are functioning properly. It's also worth considering that there could be other seasonal factors that could impact both the garage sale data and the AC quality data. For example, if there are holidays or events that occur during the summer months that draw people's attention away from these activities, it could lead to a decrease in the number of garage sales or AC upgrades that take place. Without more information, it's difficult to draw any firm conclusions about the relationship between the two distributions. However, it is definitely worth considering the various factors that could be influencing these trends.</b> (This is all fluff! And inaccurate, theres no relationship between the garage type and the AC quality)</p>
#
#
# <p style = "font-size: 16px;">It is worth noting that our analysis only covers a specific time period, and it is possible that the relationships between amenities and seasonal sales could differ in other time periods or in different geographic regions. Further research would be needed to confirm or refine these findings. We found that there was a significant difference in the number of houses sold during the summer months compared to the winter months, with more houses being sold in the summer months. We also found evidence of a correlation between the number of houses sold and the amenities that the houses contain, particularly with regard to porches and AC units.</p>
# <p style = "font-size: 16px;">Therefore, we can conclude that there is a significant difference in the number of houses sold during the summer months compared to the winter months, and there is a correlation between the number of houses sold and the amenities that the houses contain. This finding is supported by the data that we analyzed and suggests that both the season in which a house is sold and the amenities that it has can influence the number of houses that are sold. <b>This allows us to confidently reject the null hypothesis.</b></p>
#
# <p>^^NOTE: Not sure if this is right. Find out the accurate p values.  A p-value greater than 0.05 means that deviation from the null hypothesis is not statistically significant, and the null hypothesis is not rejected. Pretty sure we fail to reject the null hypothesis in this case. Double check the p-values though</p>
